# %%
import os
import numpy as np
import pywt
import random
import seaborn as sns
import tensorflow as tf
from keras.layers import Add
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (
  Input, Conv1D, BatchNormalization, Activation, GlobalAveragePooling1D, 
  Dense, Dropout, GRU, Concatenate, LayerNormalization, MultiHeadAttention, 
  Reshape, Multiply, Softmax
)
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from utils import (
  encode_labels, check_gpu_availability, plot_loss_accuracytupian, 
  evaluate_model, plot_confusion_matrixtupian, plot_tsne, 
  plot_precision_recall_curve_multiclasstupian, plot_roc_curve_multiclasstupian, 
  AdjustLearningRateCallback, denoise2,count_labels,denoise2_iterative2,AdjustLearningRateCallback
)
from utils import plot_precision_recall_curve_multiclass,plot_roc_curve_multiclass2,calculate_g_mean,plot_confusion_matrix,plot_confusion_matrix2,plot_loss_accuracy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv1DTranspose
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.20.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
check_gpu_availability()
# Out:
# GPU 可用

# %%
# 加载数据
datafilename1 = "C:\\Users\\Administrator\\Desktop\\MFEG\\dataprocessing\\cinc2017denoise.npz"
data1 = np.load(datafilename1, allow_pickle=True)
X_train, y_train, X_val, y_val, X_test, y_test = data1['ecgstrain'], data1['labelstrain'], data1['ecgsval'], data1['labelsval'], data1['ecgstest'], data1['labelstest']

# %%
y_train = encode_labels(y_train)
y_test = encode_labels(y_test)
y_val= encode_labels(y_val)
y_train = to_categorical(y_train, num_classes=4)
y_val=to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# %%
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Concatenate

def ince_block(inputs, filters, strides=1):
    x1 = Conv1D(filters, 3, strides=strides, padding='same')(inputs)
    x1 = BatchNormalization()(x1)
    x1 = Activation('relu')(x1)

    x2 = Conv1D(filters, 5, strides=1, padding='same')(inputs)
    x2 = BatchNormalization()(x2)
    x2 = Activation('relu')(x2)

    x3 = Conv1D(filters, 9, strides=1, padding='same')(inputs)
    x3 = BatchNormalization()(x3)
    x3 = Activation('relu')(x3)

    x4 = Conv1D(filters, 17, strides=1, padding='same')(inputs)
    x4 = BatchNormalization()(x4)
    x4 = Activation('relu')(x4)

    x = Concatenate()([x1, x2, x3, x4])
    x = Activation('relu')(x)
    return x

# %%
from tensorflow.keras.layers import GlobalAveragePooling1D, Reshape, Dense, Multiply
def se_block(input_tensor, reduction_ratio=16):
  channels = input_tensor.shape[-1]
  x = GlobalAveragePooling1D()(input_tensor)
  x = Reshape((1, channels))(x)
  x = Dense(channels // reduction_ratio, activation='relu', use_bias=False)(x)
  x = Dense(channels, activation='sigmoid', use_bias=False)(x)
  x = Multiply()([input_tensor, x])
  return x

# %%
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Dense, GRU
from tensorflow.keras.models import Model
import tensorflow as tf

def residual_shrinkage_block_1d(incoming, nb_blocks, out_channels, downsample=False, downsample_strides=2, activation='relu', kernel_size=31,batch_norm=True, bias=True, weights_init='variance_scaling', bias_init='zeros', regularizer='l2', weight_decay=0.0001, trainable=True, name="ResidualShrinkageBlock"):
  residual = incoming
  in_channels = incoming.shape[-1]
  for i in range(nb_blocks):
    identity = residual
    if downsample:
      downsample_strides = 2
    else:
      downsample_strides = 1
    
    if batch_norm:
      residual = BatchNormalization()(residual)
    residual = Activation(activation)(residual)
    residual = Conv1D(out_channels, kernel_size=kernel_size, strides=downsample_strides, padding='same', kernel_initializer=weights_init, use_bias=bias, kernel_regularizer=regularizer, bias_regularizer=regularizer)(residual)
    
    if batch_norm:
      residual = BatchNormalization()(residual)
    residual = Activation(activation)(residual)
    residual = Conv1D(out_channels, kernel_size=kernel_size, strides=1, padding='same', kernel_initializer=weights_init, use_bias=bias, kernel_regularizer=regularizer, bias_regularizer=regularizer)(residual)
    
    # Thresholding
    abs_mean = tf.reduce_mean(tf.abs(residual), axis=1, keepdims=True)
    scales = Dense(out_channels // 4, activation='linear', kernel_regularizer=regularizer, kernel_initializer=weights_init)(abs_mean)
    scales = BatchNormalization()(scales)
    scales = Activation('relu')(scales)
    scales = Dense(out_channels, activation='linear', kernel_regularizer=regularizer, kernel_initializer=weights_init)(scales)
    scales = tf.sigmoid(scales)
    thres = abs_mean * scales
    residual = tf.sign(residual) * tf.maximum(tf.abs(residual) - thres, 0)
    
    # Downsampling and projection
    if downsample_strides > 1:
      identity = Conv1D(out_channels, 1, strides=downsample_strides, padding='same', kernel_initializer=weights_init, use_bias=bias, kernel_regularizer=regularizer, bias_regularizer=regularizer)(identity)
    
    if in_channels != out_channels or downsample:
      identity = Conv1D(out_channels, 1, strides=1, padding='same', kernel_initializer=weights_init, use_bias=bias, kernel_regularizer=regularizer, bias_regularizer=regularizer)(identity)
    
    residual = residual + identity

  return residual

# %%
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Add

def res_block31_dilated_causal(inputs, filters, kernel_size=31, dilation_rate=2,strides=1):
  shortcut = inputs
  # 使用扩张卷积和因果卷积
  x = Conv1D(filters, kernel_size, strides=1, padding='causal', dilation_rate=dilation_rate)(inputs)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv1D(filters, kernel_size, strides=1, padding='causal', dilation_rate=dilation_rate)(x)
  x = BatchNormalization()(x)
  
  # 调整shortcut路径以匹配主路径的维度
  if inputs.shape[-1] != filters:
    shortcut = Conv1D(filters, 1, strides=strides, padding='causal')(inputs)  
    shortcut = BatchNormalization()(shortcut)
  
  x = Add()([x, shortcut])
  x = Activation('relu')(x)
  return x

# %%
def res_block31(inputs, filters, kernel_size=31, strides=1):
    shortcut = inputs
    
    x = Conv1D(filters, kernel_size, strides=strides, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv1D(filters, kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    
    if strides != 1 or inputs.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, strides=strides, padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)
    
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def resxnet(num_classes=4):
    input_1 = Input(shape=(4500,1))
    x = Conv1D(64, 12, strides=2, padding='same')(input_1)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = ince_block(x,64)
    x = residual_shrinkage_block_1d(x, nb_blocks=1, out_channels=64, downsample=True)
    x = res_block31_dilated_causal(x, 32,31,2,1)
    x = se_block(x,32)
    x = residual_shrinkage_block_1d(x, nb_blocks=1, kernel_size=16,out_channels=32, downsample=True)
    x = res_block31_dilated_causal(x, 64,16,2,1)
    x = se_block(x,64)
    x = res_block31(x, 128, kernel_size=9,strides=2)
    x = res_block31(x, 256, kernel_size=6,strides=2)
    x = res_block31(x, 512, kernel_size=3,strides=2)
    x = Dropout(0.2)(x)
    x = GRU(256, return_sequences=False)(x)
    x = Dropout(0.1)(x)
    x = Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=input_1, outputs=x)
    return model

# %%
model = resxnet()
model.summary()
callback = AdjustLearningRateCallback(factor=0.1, patience=2, min_lr=1e-8)
early_stopping = EarlyStopping(monitor='val_loss', patience=7)
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
history=model.fit(X_train, y_train, batch_size=512, epochs=80, validation_data=(X_val, y_val), callbacks=[callback,early_stopping])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 4500, 1)]    0
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 2250, 64)     832         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 2250, 64)     256         conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 2250, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 2250, 64)     12352       activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 2250, 64)     20544       activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 2250, 64)     36928       activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 2250, 64)     69696       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 2250, 64)     256         conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 2250, 64)     256         conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2250, 64)     256         conv1d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2250, 64)     256         conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 2250, 64)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 2250, 64)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2250, 64)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2250, 64)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2250, 256)    0           activation_12[0][0]
#                                                                  activation_13[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2250, 256)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2250, 256)    1024        activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2250, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1125, 64)     507968      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1125, 64)     256         conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1125, 64)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1125, 64)     12352       activation_18[0][0]
# __________________________________________________________________________________________________
# tf.math.abs_2 (TFOpLambda)      (None, 1125, 64)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None, 1, 64)        0           tf.math.abs_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 16)        1040        tf.math.reduce_mean_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 16)        64          dense_4[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 1, 16)        0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 64)        1088        activation_19[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_1 (TFOpLambda)  (None, 1, 64)        0           dense_5[0][0]
# __________________________________________________________________________________________________
# tf.math.abs_3 (TFOpLambda)      (None, 1125, 64)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 1, 64)        0           tf.math.reduce_mean_1[0][0]
#                                                                  tf.math.sigmoid_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 1125, 64)     0           tf.math.abs_3[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.math.sign_1 (TFOpLambda)     (None, 1125, 64)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_1 (TFOpLambda)  (None, 1125, 64)     0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1125, 64)     16448       activation_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 1125, 64)     0           tf.math.sign_1[0][0]
#                                                                  tf.math.maximum_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 1125, 64)     4160        conv1d_19[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 1125, 64)     0           tf.math.multiply_3[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 1125, 32)     63520       tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1125, 32)     128         conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1125, 32)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 1125, 32)     31776       activation_20[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 1125, 32)     2080        tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1125, 32)     128         conv1d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1125, 32)     128         conv1d_23[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1125, 32)     0           batch_normalization_20[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 1125, 32)     0           add_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 32)           0           activation_21[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 32)        0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1)         32          reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 32)        32          dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1125, 32)     0           activation_21[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 1125, 32)     128         multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1125, 32)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 563, 32)      16416       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 563, 32)      128         conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 563, 32)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 563, 32)      3104        activation_23[0][0]
# __________________________________________________________________________________________________
# tf.math.abs_4 (TFOpLambda)      (None, 563, 32)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_2 (TFOpLamb (None, 1, 32)        0           tf.math.abs_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 8)         264         tf.math.reduce_mean_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 1, 8)         32          dense_8[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 1, 8)         0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 32)        288         activation_24[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_2 (TFOpLambda)  (None, 1, 32)        0           dense_9[0][0]
# __________________________________________________________________________________________________
# tf.math.abs_5 (TFOpLambda)      (None, 563, 32)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 1, 32)        0           tf.math.reduce_mean_2[0][0]
#                                                                  tf.math.sigmoid_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 563, 32)      0           tf.math.abs_5[0][0]
#                                                                  tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# tf.math.sign_2 (TFOpLambda)     (None, 563, 32)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# tf.math.maximum_2 (TFOpLambda)  (None, 563, 32)      0           tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 563, 32)      1056        multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 563, 32)      0           tf.math.sign_2[0][0]
#                                                                  tf.math.maximum_2[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 563, 32)      1056        conv1d_26[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 563, 32)      0           tf.math.multiply_5[0][0]
#                                                                  conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 563, 64)      32832       tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 563, 64)      256         conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 563, 64)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 563, 64)      65600       activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 563, 64)      2112        tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 563, 64)      256         conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 563, 64)      256         conv1d_30[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 563, 64)      0           batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 563, 64)      0           add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 64)           0           activation_26[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 64)        0           global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1)         64          reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 64)        64          dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 563, 64)      0           activation_26[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 282, 128)     73856       multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 282, 128)     512         conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 282, 128)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 282, 128)     147584      activation_27[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 282, 128)     8320        multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 282, 128)     512         conv1d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 282, 128)     512         conv1d_33[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 282, 128)     0           batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 282, 128)     0           add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 141, 256)     196864      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 141, 256)     1024        conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 141, 256)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 141, 256)     393472      activation_29[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 141, 256)     33024       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 141, 256)     1024        conv1d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 141, 256)     1024        conv1d_36[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 141, 256)     0           batch_normalization_32[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 141, 256)     0           add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 71, 512)      393728      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 71, 512)      2048        conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 71, 512)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 71, 512)      786944      activation_31[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 71, 512)      131584      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 71, 512)      2048        conv1d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 71, 512)      2048        conv1d_39[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 71, 512)      0           batch_normalization_35[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 71, 512)      0           add_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 71, 512)      0           activation_32[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 256)          591360      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           gru[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 4)            1028        dropout_1[0][0]
# ==================================================================================================
# Total params: 3,676,284
# Trainable params: 3,668,876
# Non-trainable params: 7,408
# __________________________________________________________________________________________________
# Epoch 1/80
#  6/28 [=====>........................] - ETA: 14s - loss: 5.3806 - accuracy: 0.5423WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2272s vs `on_train_batch_end` time: 0.3627s). Check your callbacks.
# 28/28 [==============================] - 57s 981ms/step - loss: 4.4762 - accuracy: 0.5822 - val_loss: 3.4826 - val_accuracy: 0.5755
# Epoch 2/80
# 28/28 [==============================] - 19s 676ms/step - loss: 2.8531 - accuracy: 0.6653 - val_loss: 2.4613 - val_accuracy: 0.5777
# Epoch 3/80
# 28/28 [==============================] - 19s 679ms/step - loss: 2.0290 - accuracy: 0.7404 - val_loss: 2.0155 - val_accuracy: 0.5766
# Epoch 4/80
# 28/28 [==============================] - 19s 681ms/step - loss: 1.5366 - accuracy: 0.7754 - val_loss: 1.6357 - val_accuracy: 0.5782
# Epoch 5/80
# 28/28 [==============================] - 19s 683ms/step - loss: 1.2025 - accuracy: 0.8024 - val_loss: 1.4256 - val_accuracy: 0.5755
# Epoch 6/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.9698 - accuracy: 0.8148 - val_loss: 1.3903 - val_accuracy: 0.5755
# Epoch 7/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.8059 - accuracy: 0.8194 - val_loss: 1.2139 - val_accuracy: 0.5755
# Epoch 8/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.6778 - accuracy: 0.8268 - val_loss: 1.1381 - val_accuracy: 0.5755
# Epoch 9/80
# 28/28 [==============================] - 19s 685ms/step - loss: 0.5865 - accuracy: 0.8338 - val_loss: 0.9123 - val_accuracy: 0.5755
# Epoch 10/80
# 28/28 [==============================] - 19s 685ms/step - loss: 0.5115 - accuracy: 0.8428 - val_loss: 0.9201 - val_accuracy: 0.5766
# Epoch 11/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.4561 - accuracy: 0.8414 - val_loss: 0.7242 - val_accuracy: 0.5793
# Epoch 12/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.4056 - accuracy: 0.8485 - val_loss: 0.6544 - val_accuracy: 0.6169
# Epoch 13/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.3696 - accuracy: 0.8522 - val_loss: 0.6039 - val_accuracy: 0.6507
# Epoch 14/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.3442 - accuracy: 0.8531 - val_loss: 0.4932 - val_accuracy: 0.6823
# Epoch 15/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.3114 - accuracy: 0.8611 - val_loss: 0.4958 - val_accuracy: 0.7161
# Epoch 16/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.2832 - accuracy: 0.8697 - val_loss: 0.4332 - val_accuracy: 0.7351
# Epoch 17/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.2748 - accuracy: 0.8666 - val_loss: 0.3291 - val_accuracy: 0.8163
# Epoch 18/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.2475 - accuracy: 0.8770 - val_loss: 0.3079 - val_accuracy: 0.8272
# Epoch 19/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.2363 - accuracy: 0.8805 - val_loss: 0.3292 - val_accuracy: 0.8071
# Epoch 20/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.2305 - accuracy: 0.8783 - val_loss: 0.2873 - val_accuracy: 0.8376
# Epoch 21/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.2088 - accuracy: 0.8911 - val_loss: 0.3193 - val_accuracy: 0.8158
# Epoch 22/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.1965 - accuracy: 0.8980 - val_loss: 0.2741 - val_accuracy: 0.8474
# Epoch 23/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.1918 - accuracy: 0.8988 - val_loss: 0.3668 - val_accuracy: 0.8038
# Epoch 24/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.1770 - accuracy: 0.9097 - val_loss: 0.2847 - val_accuracy: 0.8365
# Reduced learning rate to 0.00010000000474974513.
# Epoch 25/80
# 28/28 [==============================] - 19s 684ms/step - loss: 0.1348 - accuracy: 0.9420 - val_loss: 0.2258 - val_accuracy: 0.8790
# Epoch 26/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.1045 - accuracy: 0.9644 - val_loss: 0.2512 - val_accuracy: 0.8665
# Epoch 27/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.0898 - accuracy: 0.9734 - val_loss: 0.2817 - val_accuracy: 0.8534
# Reduced learning rate to 1.0000000656873453e-05.
# Epoch 28/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.0782 - accuracy: 0.9822 - val_loss: 0.2664 - val_accuracy: 0.8681
# Epoch 29/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.0765 - accuracy: 0.9833 - val_loss: 0.2605 - val_accuracy: 0.8730
# Reduced learning rate to 1.0000001111620804e-06.
# Epoch 30/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.0748 - accuracy: 0.9846 - val_loss: 0.2509 - val_accuracy: 0.8757
# Epoch 31/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.0746 - accuracy: 0.9850 - val_loss: 0.2448 - val_accuracy: 0.8779
# Reduced learning rate to 1.0000001537946446e-07.
# Epoch 32/80
# 28/28 [==============================] - 19s 683ms/step - loss: 0.0745 - accuracy: 0.9851 - val_loss: 0.2409 - val_accuracy: 0.8817

# %%
y_pred_classes = np.argmax(model.predict(X_test), axis=-1)
y_test_classes = np.argmax(y_test, axis=1)

# %%
evaluate_model(model,X_test,y_test)
# Out:
# Precision: 0.8643418069568964
# Recall: 0.8745726703668848
# F1 Score: 0.8685479068399242
# Accuracy: 0.8656476267095736
# Class 1 - Precision: 0.8487394957983193, Recall: 0.8898678414096917, F1 Score: 0.8688172043010752
# Class 2 - Precision: 0.889386189258312, Recall: 0.9267155229846769, F1 Score: 0.9076672104404567
# Class 3 - Precision: 0.8144796380090498, Recall: 0.7317073170731707, F1 Score: 0.7708779443254818
# Class 4 - Precision: 0.9047619047619048, Recall: 0.95, F1 Score: 0.9268292682926829
# Class 1 Accuracy: 0.9754625905068383
# Class 2 Accuracy: 0.8861625100563154
# Class 3 Accuracy: 0.8708769106999196
# Class 4 Accuracy: 0.998793242156074

# %%
plot_confusion_matrix2(y_test_classes, y_pred_classes, classes=['A', 'N', 'O', '~'])
